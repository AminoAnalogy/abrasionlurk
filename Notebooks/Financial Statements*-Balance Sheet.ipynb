# %%
#https://www.youtube.com/watch?v=1Idq74JZQts&t=780s
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import requests
import json

# %%
#https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/{quote}?period=quarter&apikey=31fa1a9122c9b0d18024b5eb2d9ef148
#used the old url that includes /financials/
quote = 'ABBV'
period = ''
def getfinancials(quote):
    r= requests.get(f"https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/{quote}?period=quarter&apikey=31fa1a9122c9b0d18024b5eb2d9ef148")
    r = r.json()
    d = r['financials']
    count = 0
    for item in d:
        if count == 0:
            d = r['financials']
            d = d[0]
            incomeinitial = pd.DataFrame(list(d.items()),columns=['item','value'])
        count = count + 1
        if count > 5:  
            continue
        d = r['financials']
        d = d[count]   

        incomeinitial2 = pd.DataFrame(list(d.items()),columns=['item','value'])
        incomeinitial = incomeinitial.merge(incomeinitial2, on="item", how= 'left')

    incomeinitial.columns = incomeinitial.iloc[0]
    incomeinitial= incomeinitial[1:]
    incomeinitial
    cols = incomeinitial.columns
    cols = cols[1:]

    incomeinitial[cols]=incomeinitial[cols].apply(pd.to_numeric, errors='coerce')
    return incomeinitial
    
incomeinitial = getfinancials(quote)

# %%
quote = 'ABBV'
assets = []
liabilities = []
equity = []

import requests

for quotes in quote:
    Balance_Sheet = requests.get(f"https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/{quote}?period=quarter&apikey=31fa1a9122c9b0d18024b5eb2d9ef148")

    Balance_Sheet = Balance_Sheet.json()
    
    asset_i = Balance_Sheet['financials'][0]['Total assets']
    assets.append(asset_i)
    
    liabilities_i = Balance_Sheet['financials'][0]['Total liabilities']
    liabilities.append(liabilities_i)
    
    equity_i = Balance_Sheet['financials'][0]['Total shareholders equity']
    equity.append(equity_i)

# %%
for quotes in quote:
    Balance_Sheet = requests.get(f"https://financialmodelingprep.com/api/v3/financials/balance-sheet-statement/{quote}?period=quarter&apikey=31fa1a9122c9b0d18024b5eb2d9ef148")

    Balance_Sheet = Balance_Sheet.json()

print(Balance_Sheet)
# Out:
# {'symbol': 'ABBV', 'financials': [{'date': '2020-03-31', 'Cash and cash equivalents': '41142000000.0', 'Short-term investments': '0.0', 'Cash and short-term investments': '41142000000.0', 'Receivables': '6362000000.0', 'Inventories': '1844000000.0', 'Total current assets': '51758000000.0', 'Property, Plant & Equipment Net': '2961000000.0', 'Goodwill and Intangible Assets': '33764000000.0', 'Long-term investments': '78000000.0', 'Tax assets': '0.0', 'Total non-current assets': '39441000000.0', 'Total assets': '91199000000.0', 'Payables': '12709000000.0', 'Short-term debt': '3756000000.0', 'Total current liabilities': '16471000000.0', 'Long-term debt': '63284000000.0', 'Total debt': '67040000000.0', 'Deferred revenue': '0.0', 'Tax Liabilities': '0.0', 'Deposit Liabilities': '0.0', 'Total non-current liabilities': '82143000000.0', 'Total liabilities': '98614000000.0', 'Other comprehensive income': '0.0', 'Retained earnings (deficit)': '5973000000.0', 'Total shareholders equity': '-7415000000.0', 'Investments': '78000000.0', 'Net Debt': '25898000000.0', 'Other Assets': '0.0', 'Other Liabilities': '0.0'}, {'date': '2019-12-31', 'Cash and cash equivalents': '39924000000.0', 'Short-term investments': '0.0', 'Cash and short-term investments': '39924000000.0', 'Receivables': '5428000000.0', 'Inventories': '1813000000.0', 'Total current assets': '49519000000.0', 'Property, Plant & Equipment Net': '2962000000.0', 'Goodwill and Intangible Assets': '34253000000.0', 'Long-term investments': '93000000.0', 'Tax assets': '0.0', 'Total non-current assets': '39596000000.0', 'Total assets': '89115000000.0', 'Payables': '11832000000.0', 'Short-term debt': '3753000000.0', 'Total current liabilities': '15585000000.0', 'Long-term debt': '62975000000.0', 'Total debt': '66728000000.0', 'Deferred revenue': '0.0', 'Tax Liabilities': '0.0', 'Deposit Liabilities': '0.0', 'Total non-current liabilities': '64105000000.0', 'Total liabilities': '97287000000.0', 'Other comprehensive income': '0.0', 'Retained earnings (deficit)': '4717000000.0', 'Total shareholders equity': '-8172000000.0', 'Investments': '93000000.0', 'Net Debt': '26804000000.0', 'Other Assets': '0.0', 'Other Liabilities': '17597000000.0'}, {'date': '2019-09-30', 'Cash and cash equivalents': '10648000000.0', 'Short-term investments': '0.0', 'Cash and short-term investments': '10648000000.0', 'Receivables': '5529000000.0', 'Inventories': '1929000000.0', 'Total current assets': '20166000000.0', 'Property, Plant & Equipment Net': '2894000000.0', 'Goodwill and Intangible Assets': '34573000000.0', 'Long-term investments': '131000000.0', 'Tax assets': '0.0', 'Total non-current assets': '39275000000.0', 'Total assets': '59441000000.0', 'Payables': '12217000000.0', 'Short-term debt': '5276000000.0', 'Total current liabilities': '17493000000.0', 'Long-term debt': '33126000000.0', 'Total debt': '38402000000.0', 'Deferred revenue': '0.0', 'Tax Liabilities': '0.0', 'Deposit Liabilities': '0.0', 'Total non-current liabilities': '34184000000.0', 'Total liabilities': '67667000000.0', 'Other comprehensive income': '0.0', 'Retained earnings (deficit)': '3673000000.0', 'Total shareholders equity': '-8226000000.0', 'Investments': '131000000.0', 'Net Debt': '27754000000.0', 'Other Assets': '0.0', 'Other Liabilities': '15990000000.0'}, {'date': '2019-06-30', 'Cash and cash equivalents': '5172000000.0', 'Short-term investments': '244000000.0', 'Cash and short-term investments': '5416000000.0', 'Receivables': '5482000000.0', 'Inventories': '1895000000.0', 'Total current assets': '15100000000.0', 'Property, Plant & Equipment Net': '2879000000.0', 'Goodwill and Intangible Assets': '36101000000.0', 'Long-term investments': '1473000000.0', 'Tax assets': '0.0', 'Total non-current assets': '42042000000.0', 'Total assets': '57142000000.0', 'Payables': '11300000000.0', 'Short-term debt': '5335000000.0', 'Total current liabilities': '16941000000.0', 'Long-term debt': '31619000000.0', 'Total debt': '36954000000.0', 'Deferred r ...

# %%
asset_i = Balance_Sheet['financials'][0]['Total assets']
assets.append(asset_i)
    
liabilities_i = Balance_Sheet['financials'][0]['Total liabilities']
liabilities.append(liabilities_i)
    
equity_i = Balance_Sheet['financials'][0]['Total shareholders equity']
equity.append(equity_i)

# %%
incomeinitial
# Out:
# 0                              date    2020-03-31    2019-12-31    2019-09-30  \
# 1         Cash and cash equivalents  4.114200e+10  3.992400e+10  1.064800e+10
# 2            Short-term investments  0.000000e+00  0.000000e+00  0.000000e+00
# 3   Cash and short-term investments  4.114200e+10  3.992400e+10  1.064800e+10
# 4                       Receivables  6.362000e+09  5.428000e+09  5.529000e+09
# 5                       Inventories  1.844000e+09  1.813000e+09  1.929000e+09
# 6              Total current assets  5.175800e+10  4.951900e+10  2.016600e+10
# 7   Property, Plant & Equipment Net  2.961000e+09  2.962000e+09  2.894000e+09
# 8    Goodwill and Intangible Assets  3.376400e+10  3.425300e+10  3.457300e+10
# 9             Long-term investments  7.800000e+07  9.300000e+07  1.310000e+08
# 10                       Tax assets  0.000000e+00  0.000000e+00  0.000000e+00
# 11         Total non-current assets  3.944100e+10  3.959600e+10  3.927500e+10
# 12                     Total assets  9.119900e+10  8.911500e+10  5.944100e+10
# 13                         Payables  1.270900e+10  1.183200e+10  1.221700e+10
# 14                  Short-term debt  3.756000e+09  3.753000e+09  5.276000e+09
# 15        Total current liabilities  1.647100e+10  1.558500e+10  1.749300e+10
# 16                   Long-term debt  6.328400e+10  6.297500e+10  3.312600e+10
# 17                       Total debt  6.704000e+10  6.672800e+10  3.840200e+10
# 18                 Deferred revenue  0.000000e+00  0.000000e+00  0.000000e+00
# 19                  Tax Liabilities  0.000000e+00  0.000000e+00  0.000000e+00
# 20              Deposit Liabilities  0.000000e+00  0.000000e+00  0.000000e+00
# 21    Total non-current liabilities  8.214300e+10  6.410500e+10  3.418400e+10
# 22                Total liabilities  9.861400e+10  9.728700e+10  6.766700e+10
# 23       Other comprehensive income  0.000000e+00  0.000000e+00  0.000000e+00
# 24      Retained earnings (deficit)  5.973000e+09  4.717000e+09  3.673000e+09
# 25        Total shareholders equity -7.415000e+09 -8.172000e+09 -8.226000e+09
# 26                      Investments  7.800000e+07  9.300000e+07  1.310000e+08
# 27                         Net Debt  2.589800e+10  2.680400e+10  2.775400e+10
# 28                     Other Assets  0.000000e+00  0.000000e+00  0.000000e+00
# 29                Other Liabilities  0.000000e+00  1.759700e+10  1.599000e+10
#
# 0     2019-06-30    2019-03-31    2018-12-31
# 1   5.172000e+09  4.897000e+09  7.289000e+09
# 2   2.440000e+08  3.310000e+08  7.720000e+08
# 3   5.416000e+09  5.228000e+09  8.061000e+09
# 4   5.482000e+09  5.680000e+09  5.384000e+09
# 5   1.895000e+09  1.702000e+09  1.605000e+09
# 6   1.510000e+10  1.441300e+10  1.694500e+10
# 7   2.879000e+09  2.860000e+09  2.883000e+09
# 8   3.610100e+10  3.645200e+10  3.689600e+10
# 9   1.473000e+09  1.477000e+09  1.420000e+09
# 10  0.000000e+00  0.000000e+00  0.000000e+00
# 11  4.204200e+10  4.235600e+10  4.240700e+10
# 12  5.714200e+10  5.676900e+10  5.935200e+10
# 13  1.130000e+10  1.182600e+10  1.193100e+10
# 14  5.335000e+09  1.579000e+09  1.609000e+09
# 15  1.694100e+10  1.390400e+10  1.723900e+10
# 16  3.161900e+10  3.506600e+10  3.500200e+10
# 17  3.695400e+10  3.664500e+10  3.661100e+10
# 18  0.000000e+00  0.000000e+00  0.000000e+00
# 19  0.000000e+00  0.000000e+00  0.000000e+00
# 20  0.000000e+00  0.000000e+00  0.000000e+00
# 21  3.276700e+10  3.618200e+10  3.606900e+10
# 22  6.570800e+10  6.459500e+10  6.779800e+10
# 23  0.000000e+00  0.000000e+00  0.000000e+00
# 24  3.384000e+09  4.234000e+09  3.368000e+09
# 25 -8.566000e+09 -7.826000e+09 -8.446000e+09
# 26  1.717000e+09  1.808000e+09  2.192000e+09
# 27  3.178200e+10  3.174800e+10  2.932200e+10
# 28  0.000000e+00  0.000000e+00  0.000000e+00
# 29  1.600000e+10  1.450900e+10  1.449000e+10

# %%
#firms = companies
#companies contains our list of firms e.g. ['ABBV', 'AGN'..]

fig = go.Figure(data=[
    go.Bar(name='Assets', x=quote, y=assets ),
    go.Bar(name='Liabilities', x=quote, y=liabilities),
    go.Bar(name='Equity', x=quote, y=equity)
])

fig.update_layout(barmode='stack',title = 'Balance Sheet Latest Quarter')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-56d49653925f> in <module>
#       3
#       4 fig = go.Figure(data=[
# ----> 5     go.Bar(name='Assets', x=quote, y=assets ),
#       6     go.Bar(name='Liabilities', x=quote, y=liabilities),
#       7     go.Bar(name='Equity', x=quote, y=equity)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/plotly/graph_objs/_bar.py in __init__(self, arg, alignmentgroup, base, basesrc, cliponaxis, constraintext, customdata, customdatasrc, dx, dy, error_x, error_y, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextanchor, insidetextfont, legendgroup, marker, meta, metasrc, name, offset, offsetgroup, offsetsrc, opacity, orientation, outsidetextfont, r, rsrc, selected, selectedpoints, showlegend, stream, t, text, textangle, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, tsrc, uid, uirevision, unselected, visible, width, widthsrc, x, x0, xaxis, xcalendar, xsrc, y, y0, yaxis, ycalendar, ysrc, **kwargs)
#    2877         _v = x if x is not None else _v
#    2878         if _v is not None:
# -> 2879             self["x"] = _v
#    2880         _v = arg.pop("x0", None)
#    2881         _v = x0 if x0 is not None else _v
#
# ~/opt/anaconda3/lib/python3.7/site-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    3977                 # ### Handle simple property ###
#    3978                 else:
# -> 3979                     self._set_prop(prop, value)
#    3980             else:
#    3981                 # Make sure properties dict is initialized
#
# ~/opt/anaconda3/lib/python3.7/site-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    4295                 return
#    4296             else:
# -> 4297                 raise err
#    4298
#    4299         # val is None
#
# ~/opt/anaconda3/lib/python3.7/site-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    4290
#    4291         try:
# -> 4292             val = validator.validate_coerce(val)
#    4293         except ValueError as err:
#    4294             if self._skip_invalid:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v)
#     389             v = to_scalar_or_list(v)
#     390         else:
# --> 391             self.raise_invalid_val(v)
#     392         return v
#     393
#
# ~/opt/anaconda3/lib/python3.7/site-packages/_plotly_utils/basevalidators.py in raise_invalid_val(self, v, inds)
#     283                 typ=type_str(v),
#     284                 v=repr(v),
# --> 285                 valid_clr_desc=self.description(),
#     286             )
#     287         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'x' property of bar
#         Received value: 'ABBV'
#
#     The 'x' property is an array that may be specified as a tuple,
#     list, numpy array, or pandas Series

# %%
REV = incomeinitial[incomeinitial['date'] == 'Revenue'].iloc[0][1]
COGs = incomeinitial[incomeinitial['date'] == 'Cost of Revenue'].iloc[0][1]*-1
GrossProfit = incomeinitial[incomeinitial['date'] == 'Gross Profit'].iloc[0][1]
RD = incomeinitial[incomeinitial['date'] == 'R&D Expenses'].iloc[0][1]*-1
GA = incomeinitial[incomeinitial['date'] == 'SG&A Expense'].iloc[0][1]*-1
OperExp = incomeinitial[incomeinitial['date'] == 'Operating Expenses'].iloc[0][1]*-1
INT = incomeinitial[incomeinitial['date'] == 'Interest Expense'].iloc[0][1]*-1
EBT = incomeinitial[incomeinitial['date'] == 'Earnings before Tax'].iloc[0][1]
IncTax = incomeinitial[incomeinitial['date'] == 'Income Tax Expense'].iloc[0][1]*-1
NetInc = incomeinitial[incomeinitial['date'] == 'Net Income Com'].iloc[0][1]

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Waterfall(
    name = "20", orientation = "v",
    measure = ["relative", "relative", "total", "relative", "relative", "total", "relative", "total"],
    x = ["Revenue", "Cost of Revenue", "Gross Profit", "R&D Expenses", "SG&A Expense", "Operating Expenses", "Interest Expense", "Earnings before Tax", "Income Tax Expense", "Net Income Com"],
    textposition = "outside",
    text = [REV/1000, COGs/1000, GrossProfit/1000, RD/1000, GA/1000, OperExp/1000, INT/1000, EBT/1000, IncTax/1000, NetInc/1000],
    y = [REV, COGs, GrossProfit, RD, GA, OperExp, INT, EBT, IncTax, NetInc],
    connector = {"line":{"color":"rgba(63, 63, 63, 0.7)"}},
    decreasing = {"marker":{"color":"rgba(219, 64, 82, 0.7)"}},
    increasing = {"marker":{"color":"rgba(50, 171, 96, 0.7)"}},
    totals = {"marker":{"color":"rgba(55, 128, 192, 0.7)"}},
            
      
))

fig.update_layout(
        title = "Income Statement – Last Quarter",
        showlegend = False
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3ac23313eab8> in <module>
#       6     x = ["Revenue", "Cost of Revenue", "Gross Profit", "R&D Expenses", "SG&A Expense", "Operating Expenses", "Interest Expense", "Earnings before Tax", "Income Tax Expense", "Net Income Com"],
#       7     textposition = "outside",
# ----> 8     text = [REV/1000, COGs/1000, GrossProfit/1000, RD/1000, GA/1000, OperExp/1000, INT/1000, EBT/1000, IncTax/1000, NetInc/1000],
#       9     y = [REV, COGs, GrossProfit, RD, GA, OperExp, INT, EBT, IncTax, NetInc],
#      10     connector = {"line":{"color":"rgba(63, 63, 63, 0.7)"}},
#
# NameError: name 'REV' is not defined

# %%
Just Playing After this

# %%
import plotly.io as pio
pio.renderers

# %%
import plotly.graph_objects as go
fig = go.Figure(
    data=[go.Bar(y=[2, 1, 3])],
    layout_title_text="A Figure Displayed with the 'svg' Renderer"
)
fig.show(renderer="svg")

# %%
import plotly.graph_objects as go
import numpy as np
np.random.seed(1)

N = 100
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
sz = np.random.rand(N) * 30

fig = go.Figure()
fig.add_trace(go.Scatter(
    x=x,
    y=y,
    mode="markers",
    marker=go.scatter.Marker(
        size=sz,
        color=colors,
        opacity=0.6,
        colorscale="Viridis"
    )
))

fig.show(renderer="svg")
